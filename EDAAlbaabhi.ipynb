# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\abhishek kumar\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# C:\Users\abhishek kumar\AppData\Local\Temp\ipykernel_17624\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\abhishek kumar\Downloads.csv\automobile.csv")

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
#
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
#data cleaning handling empty value
df.replace("?",np.nan,inplace= True)

# %%
df.head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2               NaN         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1               NaN         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0               NaN         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# To check distrubution of null value we are using heat map
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
# avg_stroke= df['stroke'].astype('float').mean(axis=0)
# avg_stroke
# df['stroke'].replace(np.nan,avg_stroke,inplace=True)
df.dropna(subset=['price','peak-rpm','horsepower','stroke','bore','num-of-doors'],axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    34
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
missing = df.isnull()
for column in missing.columns.values.tolist():
    
    print(column)
    
    print(missing[column].value_counts())
    
    
    print(' ')
# Out:
# symboling
# symboling
# False    193
# Name: count, dtype: int64
#
# normalized-losses
# normalized-losses
# False    159
# True      34
# Name: count, dtype: int64
#
# make
# make
# False    193
# Name: count, dtype: int64
#
# fuel-type
# fuel-type
# False    193
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    193
# Name: count, dtype: int64
#
# num-of-doors
# num-of-doors
# False    193
# Name: count, dtype: int64
#
# body-style
# body-style
# False    193
# Name: count, dtype: int64
#
# drive-wheels
# drive-wheels
# False    193
# Name: count, dtype: int64
#
# engine-location
# engine-location
# False    193
# Name: count, dtype: int64
#
# wheel-base
# wheel-base
# False    193
# Name: count, dtype: int64
#
# length
# length
# False    193
# Name: count, dtype: int64
#
# width
# width
# False    193
# Name: count, dtype: int64
#
# height
# height
# False    193
# Name: count, dtype: int64
#
# curb-weight
# curb-weight
# False    193
# Name: count, dtype: int64
# ...

# %%
mean = df['normalized-losses'].astype('float').mean()
mean
# Out:
# 121.13207547169812

# %%
df['normalized-losses'].replace(np.nan,mean,inplace=True)

# df['normalized-losses'].fillna(value=mean,inplace =True)
# Out:
# C:\Users\abhishek kumar\AppData\Local\Temp\ipykernel_17624\3154102807.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['normalized-losses'].replace(np.nan,mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3        121.132075  alfa-romero       gas        std          two
# 1          3        121.132075  alfa-romero       gas        std          two
# 2          1        121.132075  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df[['normalized-losses','bore','stroke']]=df[['normalized-losses','bore','stroke']].astype('float')

# %%
df[['horsepower','peak-rpm','price']] =df[['horsepower','peak-rpm','price']].astype('int')

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int32
# peak-rpm               int32
# city-mpg               int64
# highway-mpg            int64
# price                  int32
# dtype: object

# %% [markdown]
# #Handling duplicate values

# %%
data={'name':['abhi','sanje','thapa','abhi'],
     'age':[10,20,30,10],
     'stream':['art','commer','science','art']}
mpg=pd.DataFrame(data)

# %%
mpg
# Out:
#     name  age   stream
# 0   abhi   10      art
# 1  sanje   20   commer
# 2  thapa   30  science
# 3   abhi   10      art

# %%
# showing true at duplicated value
mpg.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
# to drop duplicates
mpg.drop_duplicates(inplace=True)

# %%
mpg
# Out:
#     name  age   stream
# 0   abhi   10      art
# 1  sanje   20   commer
# 2  thapa   30  science

# %%
# to check how many duplicated value are there
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # outliers

# %%
sns.boxplot(x='price',data=df)
plt.title('box plot')
# Out:
# Text(0.5, 1.0, 'box plot')

# %%
Q1,Q3=df['price'].quantile([.25,.75])
IQR= Q3-Q1
LL=Q1-1.5*(IQR)
UR=Q3+1.5*(IQR)

# %%
print(LL,UR)
# Out:
# -5427.5 29680.5

# %%
def limit_imputer(x):
    if x>UR:
        return UR
    if x<LL:
        return LL
    else:
        return x

# %%
df['price'] =df['price'].apply(limit_imputer)

# %%
sns.boxplot(x='price',data=df)
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# # Q1. Check whether is there any relation between H.P. and Price with engine type

# %%
sns.scatterplot(x='horsepower',y='price',data=df,hue='engine-type')
plt.title('Correlation')
plt.show()

# %% [raw]
# There is a positive correlation (0.82) b/w Price and horsepower.If H.P. is high price will be High
# *Ohc Engine type is more in use from 50-175 H.P.Ohc engine type has long range of price from 5000 - 30000
# *ohcv Engine type has maximum horsepower 250+ with highest price.
# * I engine type mostly has 100 Horsepower from 10000-20000.
# * dohc Engine type has least vehicle

# %%
data1=df[['horsepower','price']]
sns.heatmap(data1.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int32
# peak-rpm               int32
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# # Q2. Which drive wheel has High price and which has least

# %%
sns.boxplot(x='drive-wheels',y='price',data=df)
plt.show()

# %% [raw]
# Result:
# * rwd has highest price with mean of 17500
# * lowest price is for fwd drive wheels

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3         121.132075  alfa-romero       gas        std
# 1          3         121.132075  alfa-romero       gas        std
# 2          1         121.132075  alfa-romero       gas        std
# 3          2         164.000000         audi       gas        std
# 4          2         164.000000         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# # Q3. Check correlation of all parameters with Price.

# %%
data1=df.drop(['make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','fuel-system','engine-type','num-of-cylinders','fuel-system'],axis=1)

# %%
# Removed all categorical value to check correlation
data1.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.454042   -0.536516 -0.363194
# normalized-losses   0.454042           1.000000   -0.045780  0.029772
# wheel-base         -0.536516          -0.045780    1.000000  0.879307
# length             -0.363194           0.029772    0.879307  1.000000
# width              -0.247741           0.090695    0.818465  0.857368
# height             -0.517803          -0.355541    0.591239  0.491050
# curb-weight        -0.231086           0.104469    0.782173  0.882694
# engine-size        -0.068327           0.138074    0.568375  0.686998
# bore               -0.144785          -0.028097    0.495957  0.606373
# stroke             -0.010884           0.053710    0.174225  0.121888
# compression-ratio  -0.175160          -0.112888    0.252234  0.156061
# horsepower          0.069491           0.213262    0.377040  0.589650
# ...

# %% [raw]
# Result:
# *Length,width,height,curb-weight,engine-size, bore,horsepower have positive coorelation
# *peak-rpm,city-mpg,highway-mpg and symboling have negative correlation

# %% [markdown]
# # Q4.Which price range have maximum cars

# %%
sns.histplot(x=df['price'])
plt.title('Price range')
plt.show()
# Out:
# C:\Users\abhishek kumar\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [raw]
# Result
# * We have 40-50 count for price 5000 -10000
# * Least count is for 25000 approx 3

# %% [markdown]
# # Q5. Which body type has highest and lowest price?

# %%
sns.boxplot(x='body-style',y='price',data=df)
plt.show()

# %% [raw]
# Result:
# *Sedan,hardop and convertible have highest price
# * hatchback has lowest price

# %% [markdown]
# # Q6. Which company have highest and lowest count

# %%
plt.figure(figsize=(25, 6)) 
sns.histplot(x='make',data=df)
plt.show()
# Out:
# C:\Users\abhishek kumar\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [raw]
# Result:
# * Toyota has maximum numbers of vehicles
# * Mercury make is at the bottom

# %%
df['fuel-type'].value_counts()
# Out:
# fuel-type
# gas       174
# diesel     19
# Name: count, dtype: int64

# %% [markdown]
# # Q7. Which body-type has better mileage also check which fuel type is better?

# %%
plt.figure(figsize=(18,6))
plt.subplot(2,1,1)
sns.boxplot(x='body-style',y='city-mpg',hue='fuel-type',data=df)
plt.title('city Mileage of diff body-style')
plt.subplot(2,1,2)
sns.boxplot(x='body-style',y='highway-mpg',hue='fuel-type',data=df)
plt.title('Highway Mileage of diff body-style')
plt.tight_layout()
plt.show()

# %% [raw]
# Result:
# *In city miles per gallon hatchback body style give better Mileage which is of gas fuel followed by Sedan body style with diesel
# *In Highway Miles per gallon hatchback body style give better Mileage which is of gas fuel followed by Sedan body style with diesel
# Conclusion:
# Hatchback, sedan and wagon give better fuel Economy.

# %% [markdown]
# # Q8. Is there any correlation between engine size and horsepower.How does engine and horsepower changing with Make

# %%
sns.scatterplot(x='engine-size',y='horsepower',hue='make',data=df)
plt.title('Correlation b/w Engine size and horsepower')
plt.show()

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [raw]
# Result:
# *Yes, there is a positive correlation between engine size and horsepower.
# *Increase in Engine size will increase Horsepower

# %% [markdown]
# # Q9. How does the Height, Weight and length of car body change with different body style and Make? Which body and make has Largest and smalles dimensions?

# %%
dimens=['height','length','width']
df.groupby(['body-style'] ,as_index=False)[dimens].mean().sort_values(by=dimens, ascending=False)
# Out:
#     body-style     height      length      width
# 4        wagon  56.791667  181.295833  66.245833
# 3        sedan  54.416304  178.275000  66.342391
# 1      hardtop  52.850000  176.937500  66.612500
# 2    hatchback  52.320635  165.949206  65.042857
# 0  convertible  51.433333  170.383333  65.583333

# %%
body_style = df.groupby('body-style')[dimens].mean()
body_style.plot(kind='bar', rot=0)
plt.title('Average Dimensions by Body Style')
plt.xlabel('Body Style')
plt.ylabel('Average Dimension')
plt.show()

# %%
dimens=['height','length','width']
df.groupby(['make'] ,as_index=False)[dimens].mean().sort_values(by=dimens, ascending=False)
# Out:
#              make     height      length      width
# 13         peugot  57.181818  191.136364  68.390909
# 20          volvo  56.236364  188.800000  67.963636
# 16           saab  56.100000  186.600000  66.500000
# 9   mercedes-benz  55.725000  195.262500  71.062500
# 19     volkswagen  55.183333  172.533333  65.616667
# 1            audi  54.833333  184.766667  68.850000
# 2             bmw  54.825000  184.500000  66.475000
# 10        mercury  54.800000  178.400000  68.000000
# 8           mazda  54.433333  170.825000  65.475000
# 17         subaru  53.750000  168.858333  64.950000
# 18         toyota  53.721875  171.934375  65.090625
# 12         nissan  53.633333  170.988889  65.088889
# 5           honda  53.238462  160.769231  64.384615
# 6           isuzu  52.450000  171.650000  63.500000
# 3       chevrolet  52.400000  151.933333  62.500000
# 14       plymouth  51.971429  164.900000  64.271429
# 4           dodge  51.775000  161.450000  64.212500
# ...

# %%
#
make_style = df.groupby('make')[dimens].mean()
make_style.plot(kind='bar', rot=90)
plt.title('Average Dimensions by Make')
plt.xlabel('make')
plt.ylabel('Average Dimension')
plt.show()

# %%
df.groupby(['drive-wheels'] ,as_index=False)['price'].mean().sort_values(by='price', ascending=False)
# Out:
#   drive-wheels         price
# 2          rwd  18897.591549
# 0          4wd  10241.000000
# 1          fwd   9231.061404

# %% [raw]
# Result:
# * By Body style Wagon has Highest Height, length,Width and Lowest is convertible
# *By Make peugot has Highest Height, length,Width and Lowest is alfa-romero

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3         121.132075  alfa-romero       gas        std
# 1          3         121.132075  alfa-romero       gas        std
# 2          1         121.132075  alfa-romero       gas        std
# 3          2         164.000000         audi       gas        std
# 4          2         164.000000         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# # Q10. Check the correlation between curb-weight and Miles per gallon('city-mpg','highway-mpg')? Also calculate the correlation Coefficient

# %%
sns.regplot(x='curb-weight',y='city-mpg',data=df)
plt.title('correlation B/W curb- weight & city-mpg')
plt.show()

sns.regplot(x='curb-weight',y='highway-mpg',data=df)
plt.title('correlation B/W curb- weight & highway-mpg')
plt.show()

# %%
corr_city = df['curb-weight'].corr(df['city-mpg'])
corr_highway = df['curb-weight'].corr(df['highway-mpg'])
print('Correlation coefficient (Curb Weight vs. City MPG):', corr_city)
print('Correlation coefficient (Curb Weight vs. Highway MPG):', corr_highway)
# Out:
# Correlation coefficient (Curb Weight vs. City MPG): -0.7777631802346262
# Correlation coefficient (Curb Weight vs. Highway MPG): -0.8181042274125352

# %% [raw]
# Result:
# * This Negative correlation shows lower the better better will be the fuel Economy.
# * Verified with Negative Correlation Coefficient

# %%
pwd
# Out:
# 'C:\\Users\\abhishek kumar'
